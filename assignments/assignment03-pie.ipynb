# %% [markdown]
# ## Assignment 3: Pie
# Author: Cathal Redmond
# Date: 10 Dec 2025
#
#
# Requirements:
# 1. Nice pie chart of peoples email domains from the CSV file in the URL.
# 2. Download or link to the file.
# 3. Make the pie chart look nice.
# 4. Code should be well laid out.

# %%
# Import modules we will need
import pandas as pd
import requests
import csv

# %%
# define the links to the URL
url = "https://drive.google.com/uc?id=1AWPf-pJodJKeHsARQK_RHiNsE8fjPCVK&export=download"
data = pd.read_csv(url) 

#select only the email address column
emails = data.iloc[:,5]
#print it out
print(emails)
# Out:
# 0                pwarner@example.org
# 1      fergusonkatherine@example.net
# 2                fhoward@example.org
# 3              zjohnston@example.com
# 4                   elin@example.net
#                    ...
# 995           lyonsdaisy@example.net
# 996          dariusbryan@example.com
# 997           georgechan@example.org
# 998              wanda04@example.net
# 999          deannablack@example.org
# Name: Email, Length: 1000, dtype: object

# %%
# Convert emails into a list of strings so we may parse them by the @ character
emails = emails.astype(str)

#strip out the text before the domains using the partition method
domains = emails.str.partition('@')[2]
unique_domains = domains.unique()

#Count each individual domain
count_org = domains.value_counts().get('example.org')
print("Count of example.org:",count_org)
count_net = domains.value_counts().get('example.net')
print("Count of example.net:",count_net)
count_com = domains.value_counts().get('example.com')
print("Count of example.com:",count_com)
# Out:
# Count of example.org: 341
# Count of example.net: 320
# Count of example.com: 339

# %% [markdown]
# ## End of code.
# Complete on 10 Dec 2025
